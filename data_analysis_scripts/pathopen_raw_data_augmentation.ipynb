# %% [markdown]
# ### Augmented Data Preparation
#
# This code will prepare the augmented data for evaluation purposes. This will take the random images from the collected data, augment them, and then put same set of open-ended questions for all the augmentations. The purpose of this evaluation is to ensure that same set of questions/answers with multiple augmented images make complete sense

# %% [markdown]
# https://github.com/DIAGNijmegen/pathology-he-auto-augment \
# https://www.sciencedirect.com/science/article/pii/S0010482524001021?via%3Dihub \
# https://github.com/DIAGNijmegen/pathology-he-autoaugmetation

# %%
import os
import sys

# %%
# Append the directory to the system path
sys.path.append(os.path.join("/data/mn27889/path-open-data", "pathology-he-autoaugmetation/randaugment/train"))

# %%
import pandas as pd
import numpy as np
from randaugment_new_ranges import distort_image_with_randaugment
from PIL import Image
from tqdm import tqdm
import re
import random

# %% [markdown]
# #### Reading the original data

# %%
vqa_data = pd.read_csv('../data/path_open_vqa.csv')
vqa_data = vqa_data.rename(columns={vqa_data.columns[2]: 'Image1_Path',
                                    vqa_data.columns[26]: 'Image2_Path',
                                    vqa_data.columns[27]: 'Image3_Path',
                                    vqa_data.columns[28]: 'Image4_Path',
                                    vqa_data.columns[29]: 'Image5_Path',
                                    'Image 1 Magnification ': 'Image1_Mag',
                                    'Image 2 Magnification ': 'Image2_Mag',
                                    'Image 3 Magnification ': 'Image3_Mag',
                                    'Image 4 Magnification ': 'Image4_Mag',
                                    'Image 5 Magnification ': 'Image5_Mag'})

vqa_data = vqa_data.reset_index()
vqa_data['index'] = vqa_data['index'] + 1
vqa_data = vqa_data.rename(columns={'index': 'Case_ID'})
vqa_data.head()
# Out:
#    Case_ID           Timestamp Pathologist ID  \
# 0        1  2/25/2025 13:41:20             CK
# 1        2  2/25/2025 13:46:25             CK
# 2        3  2/25/2025 13:51:37             CK
# 3        4  2/26/2025 11:30:23             CK
# 4        5  2/26/2025 11:42:26             CK
#
#                                          Image1_Path  \
# 0  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4  https://drive.google.com/open?id=1VNr78I5w671g...
#
#                                  Organ         Categorization  \
# 0         Hematolymphoid - Lymph Nodes  Neoplasia (Malignant)
# 1         Hematolymphoid - Lymph Nodes  Neoplasia (Malignant)
# 2         Hematolymphoid - Lymph Nodes  Neoplasia (Malignant)
# 3  Gastrointestinal - Small Intenstine     Infection (Benign)
# 4           Gastrointestinal - Dudenum     Infection (Benign)
#
#             Regional Anatomy  \
# 0                 Lymph node
# 1                 Lymph node
# 2                 Lymph node
# 3  Intestinal villous mucosa
# 4  Intestinal villous mucosa
#
#                              Open Ended - Question 1  \
# 0  What is the primary architectural pattern obse...
# 1       What is the predominant cell type seen here?
# 2  In this mantle cell lymphoma, what is the best...
# 3  In a child with poor weight gain, what are the...
# 4  What are the main histologic features of a non...
#
#                                Open Ended - Answer 1  \
# 0                                    Nodular pattern
# 1  The main cell type observed here is a lymphocy...
# 2  The nuclei of the abnormal lymphocytes are mos...
# 3  Features that argue against celiac disease in ...
# 4  Non-necrotizing granulomas are characterized b...
#
#                                Open Ended - Answer 2  ...  \
# 0                        Germinal centers are absent  ...
# 1  These would best be characterized as small lym...  ...
# 2  This should be considered a highly cellular ti...  ...
# 3  Granulomas here are often the consequence of u...  ...
# 4                                                NaN  ...
#
#   Open Ended - Wrong Answer 1 Open Ended - Wrong Answer 2 Image2_Mag  \
# 0                         NaN                         NaN        NaN
# 1                         NaN                         NaN        NaN
# 2                         NaN                         NaN        NaN
# 3                         NaN                         NaN        NaN
# 4                         NaN                         NaN        NaN
#
#   Image3_Mag Image4_Mag Image5_Mag Image2_Path Image3_Path Image4_Path  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN        NaN         NaN         NaN         NaN
#
#   Image5_Path
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# Getting only limited columns for the image augmentations

# %%
vqa_data_filt = vqa_data[['Case_ID', 'Pathologist ID', 'Image1_Path', 'Image2_Path', 'Image3_Path']]
vqa_data_filt.head()
# Out:
#    Case_ID Pathologist ID                                        Image1_Path  \
# 0        1             CK  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1        2             CK  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2        3             CK  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3        4             CK  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4        5             CK  https://drive.google.com/open?id=1VNr78I5w671g...
#
#   Image2_Path Image3_Path
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %% [markdown]
# Separating the multiple image paths available for the same question to form multiple questions

# %%
vqa_data_filt_final = pd.DataFrame()
for index, row in vqa_data_filt.iterrows():
    # Get the first image
    image_path = row['Image1_Path']
    if pd.notnull(image_path):
        row['Image_Path'] = image_path
        row['Image_ID'] = 'img_pathopen_' + str(row['Case_ID']) + '_01'
        vqa_data_filt_final = pd.concat([vqa_data_filt_final, row.to_frame().T], ignore_index=True)
    
    # Get the second image
    image_path = row['Image2_Path']
    if pd.notnull(image_path):
        row['Image_Path'] = image_path
        row['Image_ID'] = 'img_pathopen_' + str(row['Case_ID']) + '_02'
        vqa_data_filt_final = pd.concat([vqa_data_filt_final, row.to_frame().T], ignore_index=True)
    
    # Get the third image
    image_path = row['Image3_Path']
    if pd.notnull(image_path):
        row['Image_Path'] = image_path
        row['Image_ID'] = 'img_pathopen_' + str(row['Case_ID']) + '_03'
        vqa_data_filt_final = pd.concat([vqa_data_filt_final, row.to_frame().T], ignore_index=True)

vqa_data_filt_final.head()
# Out:
#   Case_ID Pathologist ID                                        Image1_Path  \
# 0       1             CK  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1       2             CK  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2       3             CK  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3       4             CK  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4       5             CK  https://drive.google.com/open?id=1VNr78I5w671g...
#
#   Image2_Path Image3_Path                                         Image_Path  \
# 0         NaN         NaN  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1         NaN         NaN  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2         NaN         NaN  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3         NaN         NaN  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4         NaN         NaN  https://drive.google.com/open?id=1VNr78I5w671g...
#
#             Image_ID
# 0  img_pathopen_1_01
# 1  img_pathopen_2_01
# 2  img_pathopen_3_01
# 3  img_pathopen_4_01
# 4  img_pathopen_5_01

# %% [markdown]
# Removing the un-necessary columns

# %%
vqa_data_filt_final = vqa_data_filt_final.drop(columns=['Image1_Path', 'Image2_Path', 'Image3_Path'])
vqa_data_filt_final.head()
# Out:
#   Case_ID Pathologist ID                                         Image_Path  \
# 0       1             CK  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1       2             CK  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2       3             CK  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3       4             CK  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4       5             CK  https://drive.google.com/open?id=1VNr78I5w671g...
#
#             Image_ID
# 0  img_pathopen_1_01
# 1  img_pathopen_2_01
# 2  img_pathopen_3_01
# 3  img_pathopen_4_01
# 4  img_pathopen_5_01

# %% [markdown]
# ### Generating the Google Sheet Containing the mapping between Google Drive Links and Image Names
#
# This will help to map the image names downloaded from collected data with the Google Drive Links we have in our data

# %%
# function listFilesInNestedFolders(parentFolderId) {
#   // Get the initial parent folder
#   var parentfolder_id = '1VdFeRx06PrTTCbeMVQ0wQ8ML8QF8sSxM-QWlTcMx7TKQAjpWRuW5-EWJi-DtuBDPeXTbGYNm'
#   const parentFolder = DriveApp.getFolderById(parentfolder_id);
#   var folderlisting = 'File Names and Links - '+ parentfolder_id;

#   var ss = SpreadsheetApp.create(folderlisting);
#   var sheet = ss.getActiveSheet();
#   sheet.appendRow(['name','link']);

#   // Get subfolders in the current folder and process them recursively
#   var subfolders = parentFolder.getFolders();
#   while (subfolders.hasNext()) {
#     var subfolder = subfolders.next();
#     // Get files in the current folder
#     var contents = subfolder.getFiles();
#     var file;
#     var name;
#     var link;
#     while (contents.hasNext()) {
#       file = contents.next();
#       name = file.getName();
#       link = file.getUrl();
#       sheet.appendRow([name,link]);
#     }
#   }
# }

# %% [markdown]
# Now Download the file generated which contains mapping between google drive links and names.

# %%
data_dir = "../data_eval"
file_name = "file_names_and_links_PathOpen_Images.csv"
file_path = os.path.join(data_dir, file_name)
google_drive_name_links = pd.read_csv(file_path)
google_drive_name_links.head()
# Out:
#                                           name  \
# 0            ck_HSP_5x - Chandra Krishnan.jpeg
# 1           ck_BALL_4x - Chandra Krishnan.jpeg
# 2   ck_pschwannoma_20x - Chandra Krishnan.jpeg
# 3  ck_CMV gastritis_4x - Chandra Krishnan.jpeg
# 4         ck_rhabdo_5x - Chandra Krishnan.jpeg
#
#                                                 link
# 0  https://drive.google.com/file/d/1SYbssi84BMfkC...
# 1  https://drive.google.com/file/d/1XrSu7uRm3s-al...
# 2  https://drive.google.com/file/d/1dGZ8MAgdKvT5w...
# 3  https://drive.google.com/file/d/11UMXpBZjiQdo0...
# 4  https://drive.google.com/file/d/174myggtY1Fj5A...

# %% [markdown]
# Extracting the ID's from image links

# %%
vqa_data_filt_final['google_drive_image_id'] = vqa_data_filt_final['Image_Path'].apply(lambda x: x.split('=')[-1])
google_drive_name_links['google_drive_image_id'] = google_drive_name_links['link'].apply(lambda x: x.split('/')[-1])

# %% [markdown]
# Combining the names of the image files

# %%
vqa_data_filt_final = pd.merge(vqa_data_filt_final, google_drive_name_links[['google_drive_image_id', 'name']], on='google_drive_image_id', how='left')
vqa_data_filt_final.head()
# Out:
#   Case_ID Pathologist ID                                         Image_Path  \
# 0       1             CK  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1       2             CK  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2       3             CK  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3       4             CK  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4       5             CK  https://drive.google.com/open?id=1VNr78I5w671g...
#
#             Image_ID              google_drive_image_id  \
# 0  img_pathopen_1_01  1tgv50Q9W4Bm_Mk7my6Ag8mD0JWkQkYvx
# 1  img_pathopen_2_01  1igYpj4RL0XKxq0u5qlnv6ZvqJfFjGO4u
# 2  img_pathopen_3_01  1DKNZJQJ17SkXUrrO7jHMiKD8J6ittzus
# 3  img_pathopen_4_01  1jUe0z6wlZ0s9PZUgVj1yCL7UZav23jwz
# 4  img_pathopen_5_01  1VNr78I5w671gkrIyHs7AC75yrjb1lU6_
#
#                                              name
# 0                  MCL_20x - Chandra Krishnan.jpg
# 1                 MCL_200x - Chandra Krishnan.jpg
# 2                 MCL_400x - Chandra Krishnan.jpg
# 3   Duodenum granuloma_40x - Chandra Krishnan.jpg
# 4  Duodenum granuloma_100x - Chandra Krishnan.jpg

# %%
vqa_data_filt_final.head(100)
# Out:
#    Case_ID Pathologist ID                                         Image_Path  \
# 0        1             CK  https://drive.google.com/open?id=1tgv50Q9W4Bm_...
# 1        2             CK  https://drive.google.com/open?id=1igYpj4RL0XKx...
# 2        3             CK  https://drive.google.com/open?id=1DKNZJQJ17SkX...
# 3        4             CK  https://drive.google.com/open?id=1jUe0z6wlZ0s9...
# 4        5             CK  https://drive.google.com/open?id=1VNr78I5w671g...
# ..     ...            ...                                                ...
# 95      96             AC  https://drive.google.com/open?id=1o3UGD4YoSFxv...
# 96      97             CK  https://drive.google.com/open?id=1h_niAtvlq6QS...
# 97      98             AC  https://drive.google.com/open?id=1DEEw5vjjecbr...
# 98      99             AC  https://drive.google.com/open?id=16FntYOr7bqU5...
# 99     100             AC  https://drive.google.com/open?id=19BCokgiMELG1...
#
#                Image_ID              google_drive_image_id  \
# 0     img_pathopen_1_01  1tgv50Q9W4Bm_Mk7my6Ag8mD0JWkQkYvx
# 1     img_pathopen_2_01  1igYpj4RL0XKxq0u5qlnv6ZvqJfFjGO4u
# 2     img_pathopen_3_01  1DKNZJQJ17SkXUrrO7jHMiKD8J6ittzus
# 3     img_pathopen_4_01  1jUe0z6wlZ0s9PZUgVj1yCL7UZav23jwz
# 4     img_pathopen_5_01  1VNr78I5w671gkrIyHs7AC75yrjb1lU6_
# ..                  ...                                ...
# 95   img_pathopen_96_01  1o3UGD4YoSFxvJFhUF0ul-0b3SYygdbSn
# 96   img_pathopen_97_01  1h_niAtvlq6QSqDqwaBiGLiyesETgUm8g
# 97   img_pathopen_98_01  1DEEw5vjjecbromHvfMyWq0SomIhDk2Xs
# 98   img_pathopen_99_01  16FntYOr7bqU5lMm_HmcvteV3v6mCn_xF
# 99  img_pathopen_100_01  19BCokgiMELG10o4zbbmt2aguGGuESuU9
#
#                                                name
# 0                    MCL_20x - Chandra Krishnan.jpg
# 1                   MCL_200x - Chandra Krishnan.jpg
# 2                   MCL_400x - Chandra Krishnan.jpg
# 3     Duodenum granuloma_40x - Chandra Krishnan.jpg
# 4    Duodenum granuloma_100x - Chandra Krishnan.jpg
# ..                                              ...
# 95                   ac_img42_20x - Amy Coffey.jpeg
# 96  ck_placental infarct_5x - Chandra Krishnan.jpeg
# 97                  ac_img43_200x - Amy Coffey.jpeg
# 98                  ac_img44_200x - Amy Coffey.jpeg
# 99                  ac_img45_100x - Amy Coffey.jpeg
#
# [100 rows x 6 columns]

# %%
vqa_data_filt_final.iloc[50:80,:]
# Out:
#    Case_ID Pathologist ID                                         Image_Path  \
# 50      51             AC  https://drive.google.com/open?id=1PQtZFlaL7ACY...
# 51      52             AC  https://drive.google.com/open?id=1E8_uUE9f7JTL...
# 52      53             AC  https://drive.google.com/open?id=1cx3M-mWgvjon...
# 53      54             CK  https://drive.google.com/open?id=1wHuKGW55lOOQ...
# 54      55             AC  https://drive.google.com/open?id=1tbuSPy8fibAG...
# 55      56             CK  https://drive.google.com/open?id=1pt7yylB_u0Os...
# 56      57             CK  https://drive.google.com/open?id=1skKiW8IPkgL4...
# 57      58             CK  https://drive.google.com/open?id=1hG0Q-JHsCS1a...
# 58      59             CK  https://drive.google.com/open?id=1gYbzHCzHyavR...
# 59      60             CK  https://drive.google.com/open?id=1XGn5eIgVUfKj...
# 60      61             CK  https://drive.google.com/open?id=1UCxGrtxEXsU0...
# 61      62             CK  https://drive.google.com/open?id=1iisbShaoX0qk...
# 62      63             CK  https://drive.google.com/open?id=1oenGyiwnXtCJ...
# 63      64             AC  https://drive.google.com/open?id=1qiBYBEmm9TXi...
# 64      65             AC  https://drive.google.com/open?id=1j8_coGLWD4C9...
# 65      66             AC  https://drive.google.com/open?id=1sT4gNeuYMV3R...
# 66      67             AC  https://drive.google.com/open?id=1iNpg3DgTGpNZ...
# 67      68             AC  https://drive.google.com/open?id=1_beSmXXPq4sV...
# 68      69             AC  https://drive.google.com/open?id=1Dml_-g8JOP4Y...
# 69      70             AC  https://drive.google.com/open?id=1oIAu4puQJaJ-...
# 70      71             CK  https://drive.google.com/open?id=1ibFWmslUJ0wq...
# 71      72             AC  https://drive.google.com/open?id=17FQY8_cJC8tX...
# 72      73             AC  https://drive.google.com/open?id=1x4N-Lf-g6Tby...
# 73      74             AC  https://drive.google.com/open?id=1W0G0fov6MkKN...
# 74      75             AC  https://drive.google.com/open?id=1n9QDIwHTADQ7...
# 75      76             AC  https://drive.google.com/open?id=1NFK0iG0ARqfp...
# 76      77             AC  https://drive.google.com/open?id=15NOn1ZIrCURd...
# 77      78             AC  https://drive.google.com/open?id=1SWy9uYqr5_Y5...
# 78      79             CK  https://drive.google.com/open?id=1avNYoJeBGrCX...
# 79      80             CK  https://drive.google.com/open?id=1q7SFWU1zbhuH...
#
#               Image_ID              google_drive_image_id  \
# 50  img_pathopen_51_01  1PQtZFlaL7ACY_7teQt3xKVGL7GL46_sV
# 51  img_pathopen_52_01  1E8_uUE9f7JTLSwoqk7yf1h7P6gcFkdS9
# 52  img_pathopen_53_01  1cx3M-mWgvjonyf0p8nNCY_kiA1SpOkfn
# 53  img_pathopen_54_01  1wHuKGW55lOOQB-3_v0apILfLM0901bP-
# 54  img_pathopen_55_01  1tbuSPy8fibAGby9LYbTonR2EcSZWojhq
# 55  img_pathopen_56_01  1pt7yylB_u0OsKPwp5KZLQ3-qsjsb5use
# 56  img_pathopen_57_01  1skKiW8IPkgL4VX2vm3nIkOsC5OgAY-Te
# 57  img_pathopen_58_01  1hG0Q-JHsCS1aGnbphDShkq4bg4e2dvP-
# 58  img_pathopen_59_01  1gYbzHCzHyavRQvjaNL_7x8ZJOe4xPMJG
# 59  img_pathopen_60_01  1XGn5eIgVUfKjxSdzj9Y3IoliEXNfav0o
# 60  img_pathopen_61_01  1UCxGrtxEXsU0ym68rOFZvcUa7BKXBbSm
# 61  img_pathopen_62_01  1iisbShaoX0qk1QTqrKVTBd0qYr2BbQKe
# 62  img_pathopen_63_01  1oenGyiwnXtCJ71_IcY5TMqK2f6jRGyRP
# 63  img_pathopen_64_01  1qiBYBEmm9TXiPjyAC43hM1TBMe6Da393
# 64  img_pathopen_65_01  1j8_coGLWD4C9ZpIerR6NYmYZEkbgVw0Y
# 65  img_pathopen_66_01  1sT4gNeuYMV3RepkLeGZBd3vr1dkffxqh
# 66  img_pathopen_67_01  1iNpg3DgTGpNZdHToSpzyOdxHAObAdkZA
# 67  img_pathopen_68_01  1_beSmXXPq4sVmHxxvKpUax7YFzI9wW9G
# 68  img_pathopen_69_01  1Dml_-g8JOP4Y3j5uRhPOHmSz23A0QGhM
# 69  img_pathopen_70_01  1oIAu4puQJaJ-Lq94lbIadtMzDvvrASR_
# 70  img_pathopen_71_01  1ibFWmslUJ0wqv70tyRnGix9uLwBOgg_g
# 71  img_pathopen_72_01  17FQY8_cJC8tXJuG9fgkPW14PFZxEdBnS
# 72  img_pathopen_73_01  1x4N-Lf-g6TbyShzxjVJ-JeO0SdbFjTyX
# 73  img_pathopen_74_01  1W0G0fov6MkKNutdbHq3rOnRn-gBftpD-
# 74  img_pathopen_75_01  1n9QDIwHTADQ7NeKzD7HuPaNDuSDP54sh
# 75  img_pathopen_76_01  1NFK0iG0ARqfpCvJnMxjTPum7h6QeuB5N
# 76  img_pathopen_77_01  15NOn1ZIrCURdrOqvhgnIvKgLyqq1Kb18
# 77  img_pathopen_78_01  1SWy9uYqr5_Y5S-4JVxLZsfsbw89T6qfE
# 78  img_pathopen_79_01  1avNYoJeBGrCXh4w2ViCxRtcsWuIveb8S
# 79  img_pathopen_80_01  1q7SFWU1zbhuHO3RYrW5Y7PV_spPUX05c
#
#                                                  name
# 50                     ac_img10_100x - Amy Coffey.jpg
# 51                     ac_img11_200x - Amy Coffey.jpg
# 52                   Case 12_ac_200x - Amy Coffey.jpg
# 53    ck_parvovirus marrow_60x - Chandra Krishnan.jpg
# 54                     ac_img13_400x - Amy Coffey.jpg
# 55             ck_serositis_4x - Chandra Krishnan.jpg
# 56  ck_helicobacter gastritis_20x - Chandra Krishn...
# 57          ck_streak ovary_2x - Chandra Krishnan.jpg
# 58      ck_testis seminoma_10x - Chandra Krishnan.jpg
# 59  ck_prostate adenocarcinoma_10x - Chandra Krish...
# 60  ck_pleomorphic adenoma_20x - Chandra Krishnan....
# 61   ck_invasive melanoma_20x - Chandra Krishnan.jpeg
# 62  ck_eosinophilic esophagitis_40x - Chandra Kris...
# 63                     ac_img15_200x - Amy Coffey.jpg
# 64                    ac_img16_200x - Amy Coffey.jpeg
# 65                     ac_img17_20x - Amy Coffey.jpeg
# 66                    ac_img18_100x - Amy Coffey.jpeg
# 67                    ac_img19_200x - Amy Coffey.jpeg
# 68                    ac_img20_200x - Amy Coffey.jpeg
# 69                    ac_img21_200x - Amy Coffey.jpeg
# 70  ck_aneurysmal bone cyst_10x - Chandra Krishnan...
# 71                    ac_img22_100x - Amy Coffey.jpeg
# 72                    ac_img23_100x - Amy Coffey.jpeg
# 73                    ac_img24_100x - Amy Coffey.jpeg
# 74                    ac_img25_200x - Amy Coffey.jpeg
# 75                    ac_img26_100x - Amy Coffey.jpeg
# 76                    ac_img27_200x - Amy Coffey.jpeg
# 77                     ac_img28_100x - Amy Coffey.jpg
# 78        ck_dermatofibroma_4x - Chandra Krishnan.jpg
# 79   ck_placenta membrane_20x - Chandra Krishnan.jpeg

# %%
vqa_data_filt_final[vqa_data_filt_final['name'] == 'ck_dermatofibroma_4x - Chandra Krishnan.jpg']
# Out:
#    Case_ID Pathologist ID                                         Image_Path  \
# 78      79             CK  https://drive.google.com/open?id=1avNYoJeBGrCX...
# 81      82             CK  https://drive.google.com/open?id=1REXrDteXd7va...
#
#               Image_ID              google_drive_image_id  \
# 78  img_pathopen_79_01  1avNYoJeBGrCXh4w2ViCxRtcsWuIveb8S
# 81  img_pathopen_82_01  1REXrDteXd7va6X_dM6sGa3Sg7yfdj2CP
#
#                                            name
# 78  ck_dermatofibroma_4x - Chandra Krishnan.jpg
# 81  ck_dermatofibroma_4x - Chandra Krishnan.jpg

# %%
vqa_data_filt_final[vqa_data_filt_final['name'] == 'ck_branchial arch_20x - Chandra Krishnan.jpg']
# Out:
#     Case_ID Pathologist ID                                         Image_Path  \
# 8         9             CK  https://drive.google.com/open?id=1GQHppS17EQxo...
# 122     121             CK  https://drive.google.com/open?id=1I-wbytP5TqHk...
#
#                 Image_ID              google_drive_image_id  \
# 8      img_pathopen_9_01  1GQHppS17EQxogC1nTB-eu7DLzr9PlSQM
# 122  img_pathopen_121_03  1I-wbytP5TqHkvU-wvnCxaPBS19hZxkNg
#
#                                              name
# 8    ck_branchial arch_20x - Chandra Krishnan.jpg
# 122  ck_branchial arch_20x - Chandra Krishnan.jpg

# %% [markdown]
# Creating a dictionary between Image_ID and name

# %%
name_imageid_dict = dict(zip(vqa_data_filt_final['name'], vqa_data_filt_final['Image_ID']))

# %%
name_imageid_dict

# %% [markdown]
# ### Reading the dataset files
#
# Preparing the augmented images for each filename

# %%
source_dataset_dir = "PathOPEN_Images"
destination_dataset_dir = "PathOPEN_Images_Augmented"
os.makedirs(destination_dataset_dir, exist_ok=True)
pathopen_file_names = os.listdir(source_dataset_dir)

# %% [markdown]
# Now peform the augmentation on these images

# %%
TOTAL_AUGMENTAIONS = 30  # Number of augmentations per image
for i in range(len(pathopen_file_names)):
    src_image = pathopen_file_names[i]
    src_image_path = os.path.join(source_dataset_dir, src_image)
    src_image_id = name_imageid_dict[src_image]
    dst_image_aug_folder = os.path.join(destination_dataset_dir, src_image_id + "_augmented")
    os.makedirs(dst_image_aug_folder, exist_ok=True)

    pil_image = Image.open(src_image_path).convert("RGB")
    np_array_img = np.array(pil_image)
    for j in tqdm(range(TOTAL_AUGMENTAIONS), desc=f"[{i+1}/{len(pathopen_file_names)}] Augmenting {src_image_id}"):
        # Apply RandAugment with specified parameters
        conv_img_arr = distort_image_with_randaugment(np_array_img, num_layers=5, magnitude=5, randomize=True, randaugment_transforms_set='custom')
        conv_img = Image.fromarray(conv_img_arr)
        conv_img.save(os.path.join(dst_image_aug_folder, src_image_id + f"_aug_{j}.png"))
